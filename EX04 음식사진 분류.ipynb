# %% [markdown]
# ### 학습 목표
# - 음식사진 종류를 분류하는 딥러닝 모델 만들기
# - 사진 데이터의 구조를 이해하기

# %% [markdown]
# ### 1. 데이터 로딩
# - https://www.kaggle.com/datasets/kmader/food41
# - 5000장의 사진을 골라서 압축한 뒤 업로드
# - 압축풀기 명령어 수행

# %% [markdown]
# #### 현재 작업 디렉토리 확인

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# #### 작업 디렉토리 변경

# %%
# %cd "./drive/MyDrive/Colab Notebooks"
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !ls
# Out:
#  data  'EX04 음식사진 분류.ipynb'   Food.zip

# %% [markdown]
# #### zip 파일 압축풀기
#
#
# ```
# !unzip "압축 풀고 싶은 파일의 위치" -d "압축을 풀어줄 위치"
# ```

# %%
# !unzip "./Food.zip" -d "./data"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: ./data/Food/train/spaghetti_bolognese/119565.jpg
#   inflating: ./data/__MACOSX/Food/train/spaghetti_bolognese/._119565.jpg
#   inflating: ./data/Food/train/spaghetti_bolognese/667586.jpg
#   inflating: ./data/__MACOSX/Food/train/spaghetti_bolognese/._667586.jpg
#   inflating: ./data/Food/train/spaghetti_bolognese/3916167.jpg
#   inflating: ./data/__MACOSX/Food/train/spaghetti_bolognese/._3916167.jpg
#   inflating: ./data/Food/train/spaghetti_bolognese/3711563.jpg
#   inflating: ./data/__MACOSX/Food/train/spaghetti_bolognese/._3711563.jpg
#   inflating: ./data/Food/train/spaghetti_bolognese/3251429.jpg
#   inflating: ./data/__MACOSX/Food/train/spaghetti_bolognese/._3251429.jpg
#   inflating: ./data/Food/train/spaghetti_bolognese/735559.jpg
#   inflating: ./data/__MACOSX/Food/train/spaghetti_bolognese/._735559.jpg
#   inflating: ./data/Food/train/spaghetti_bolognese/292277.jpg
# ...

# %% [markdown]
# #### 필요한 라이브러리 설치

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.5/974.5 kB 47.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 41.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-cls.pt")  # load a pretrained model

# Train the model
results = model.train(data="./data/Food", epochs=5, imgsz=224)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 5.52M/5.52M [00:00<00:00, 206MB/s]
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
